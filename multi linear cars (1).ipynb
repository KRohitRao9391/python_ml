# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
cars=pd.read_csv(r"C:\Users\raosu\Downloads\Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# Length: 81, dtype: bool

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.isnull()
# Out:
#        HP    MPG    VOL     SP     WT
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2   False  False  False  False  False
# 3   False  False  False  False  False
# 4   False  False  False  False  False
# ..    ...    ...    ...    ...    ...
# 76  False  False  False  False  False
# 77  False  False  False  False  False
# 78  False  False  False  False  False
# 79  False  False  False  False  False
# 80  False  False  False  False  False
#
# [81 rows x 5 columns]

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
cars.shape
# Out:
# (81, 5)

# %% [raw]
# EDA

# %% [markdown]
# # EDA

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(x=cars["HP"])
plt.show()

# %%
sns.distplot(x=cars["MPG"])
plt.title("
plt.show()
# Out:
#   Cell In[24], line 2
#     plt.title("
#               ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
sns.distplot(x=cars["VOL"],color="red")


plt.show()

# %%
sns.distplot(x=cars["WT"])
plt.title("Distribution of weight of vehicle in thousand pounds")
plt.xlabel("weight of vehicle in thousand pounds")
plt.ylabel("vehicle has more Weight")
plt.show()

# %%
sns.boxplot(x=cars["MPG"])
plt.show()

# %%
sns.boxplot(x=cars["WT"])
plt.show()

# %%
sns.boxplot(x=cars["HP"])
plt.show()

# %%
sns.boxplot(x=cars["SP"])
plt.show()

# %%
sns.boxplot(x=cars["WT"], color='red') 
plt.show()

# %%
sns.scatterplot(x=cars["VOL"],y=cars["MPG"])
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
sns.scatterplot(x=cars["HP"],y=cars["MPG"],color="red")
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %%
sns.scatterplot(x=cars["VOL"],y=cars["HP"],color="green")
# Out:
# <Axes: xlabel='VOL', ylabel='HP'>

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.heatmap(cars.corr(),cmap

# %%
sns.barplot(x=cars["HP"],y=cars['WT'],color="red")
plt.show()

# %%
sns.scatterplot(x=cars["HP"],y=cars['WT'],color="red")
plt.show()

# %%
sns.scatterplot(x=cars["HP"],y=cars['VOL'],color="red")
plt.show()

# %%
sns.scatterplot(x=cars["HP"],y=cars['SP'],color="black")
plt.show()

# %%
sns.scatterplot(x=cars["WT"],y=cars['VOL'],color="green")
plt.show()

# %%
sns.scatterplot(x=cars["WT"],y=cars['SP'],color="orange")
plt.show()

# %%
sns.scatterplot(x=cars["VOL"],y=cars['SP'],color="red")
plt.show()

# %%
sns.scatterplot(x=cars["WT"],y=cars['SP'],color="brown")
plt.show()
